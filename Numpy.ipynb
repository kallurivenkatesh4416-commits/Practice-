# %% [markdown]
# <a href="https://colab.research.google.com/github/kallurivenkatesh4416-commits/Practice-/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Conversion of string array to a float array

arr_string = np.array(['1.25', '-9.6', '42'], dtype = np.str)
arr_float = np.array(arr_string, dtype = np.float)
# Out:
# /tmp/ipython-input-3059243007.py:3: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   arr_string = np.array(['1.25', '-9.6', '42'], dtype = np.str)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3059243007.py in <cell line: 0>()
#       1 ## Conversion of string array to a float array
#       2
# ----> 3 arr_string = np.array(['1.25', '-9.6', '42'], dtype = np.str)
#       4 arr_float = np.array(arr_string, dtype = np.float)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     392
#     393         if attr in __former_attrs__:
# --> 394             raise AttributeError(__former_attrs__[attr])
#     395
#     396         if attr in __expired_attributes__:
#
# AttributeError: module 'numpy' has no attribute 'str'.
# ...
